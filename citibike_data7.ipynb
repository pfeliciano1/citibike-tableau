# %%
# Dependencies
import pandas as pd

# %%
# Name of the CSV file
file = 'Resources/JC-202107-citibike-tripdata.csv'

# %%
# Taking the file and converting into dataframe
df = pd.read_csv(file, encoding="ISO-8859-1")
df
# Out:
#                 ride_id rideable_type           started_at  \
# 0      2F01C15ECE379AE7  classic_bike  2021-07-31 13:53:26
# 1      CF7E2039ACB179C2  classic_bike  2021-07-17 19:06:01
# 2      9375052379DE50FC  classic_bike  2021-07-08 19:54:34
# 3      EF77D67D538E108E  classic_bike  2021-07-18 20:21:15
# 4      3550C64E6994B8BC  classic_bike  2021-07-08 18:19:07
# ...                 ...           ...                  ...
# 82544  908E437B7FAF3594  classic_bike  2021-07-23 15:49:32
# 82545  A7B392863F10E25F  classic_bike  2021-07-22 18:24:51
# 82546  DBF9FEE943C6FA3E  classic_bike  2021-07-23 22:40:11
# 82547  B3C1437E53E71A8F  classic_bike  2021-07-28 23:10:20
# 82548  16DF52E670465D19  classic_bike  2021-07-05 16:28:48
#
#                   ended_at          start_station_name start_station_id  \
# 0      2021-07-31 14:47:00     Bergen Ave & Stegman St            JC108
# 1      2021-07-17 19:20:07     Bergen Ave & Stegman St            JC108
# ...

# %%
df.dtypes
# Out:
# ride_id                object
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# start_station_id       object
# end_station_name       object
# end_station_id         object
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# dtype: object

# %%
# Identify incomplete rows
df.count()
# Out:
# ride_id               82549
# rideable_type         82549
# started_at            82549
# ended_at              82549
# start_station_name    82549
# start_station_id      82549
# end_station_name      81999
# end_station_id        81999
# start_lat             82549
# start_lng             82549
# end_lat               82206
# end_lng               82206
# member_casual         82549
# dtype: int64

# %%
# Drop all rows with missing information
clean_df = df.dropna(how='any')
clean_df
# Out:
#                 ride_id rideable_type           started_at  \
# 0      2F01C15ECE379AE7  classic_bike  2021-07-31 13:53:26
# 1      CF7E2039ACB179C2  classic_bike  2021-07-17 19:06:01
# 2      9375052379DE50FC  classic_bike  2021-07-08 19:54:34
# 3      EF77D67D538E108E  classic_bike  2021-07-18 20:21:15
# 4      3550C64E6994B8BC  classic_bike  2021-07-08 18:19:07
# ...                 ...           ...                  ...
# 82544  908E437B7FAF3594  classic_bike  2021-07-23 15:49:32
# 82545  A7B392863F10E25F  classic_bike  2021-07-22 18:24:51
# 82546  DBF9FEE943C6FA3E  classic_bike  2021-07-23 22:40:11
# 82547  B3C1437E53E71A8F  classic_bike  2021-07-28 23:10:20
# 82548  16DF52E670465D19  classic_bike  2021-07-05 16:28:48
#
#                   ended_at          start_station_name start_station_id  \
# 0      2021-07-31 14:47:00     Bergen Ave & Stegman St            JC108
# 1      2021-07-17 19:20:07     Bergen Ave & Stegman St            JC108
# ...

# %%
# Identify incomplete rows
clean_df.count()
# Out:
# ride_id               81999
# rideable_type         81999
# started_at            81999
# ended_at              81999
# start_station_name    81999
# start_station_id      81999
# end_station_name      81999
# end_station_id        81999
# start_lat             81999
# start_lng             81999
# end_lat               81999
# end_lng               81999
# member_casual         81999
# dtype: int64

# %%
clean_df['start date'] = pd.to_datetime(clean_df['started_at']).dt.date
clean_df['start time'] = pd.to_datetime(clean_df['started_at']).dt.time
clean_df['end date'] = pd.to_datetime(clean_df['ended_at']).dt.date
clean_df['end time'] = pd.to_datetime(clean_df['ended_at']).dt.time
clean_df
# Out:
# <ipython-input-8-582ee19bee3b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_df['start date'] = pd.to_datetime(clean_df['started_at']).dt.date
# <ipython-input-8-582ee19bee3b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_df['start time'] = pd.to_datetime(clean_df['started_at']).dt.time
# <ipython-input-8-582ee19bee3b>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# ...

# %%
renamed_df = clean_df.rename(columns={"ride_id": "rideID", "rideable_type": "rideable type", 
                                      "started_at": "start timestamp", "ended_at": "end timestamp",
                                      "start_station_name": "start station name", 
                                      "start_station_id": "start station ID", "end_station_name": "end station name", 
                                      "end_station_id": "end station ID", "start_lat": "start latitude",
                                      "start_lng": "start longitude", "end_lat": "end latitude", 
                                      "end_lng": "end longitude", "member_casual": " member/casual"})
renamed_df
# Out:
#                  rideID rideable type      start timestamp  \
# 0      2F01C15ECE379AE7  classic_bike  2021-07-31 13:53:26
# 1      CF7E2039ACB179C2  classic_bike  2021-07-17 19:06:01
# 2      9375052379DE50FC  classic_bike  2021-07-08 19:54:34
# 3      EF77D67D538E108E  classic_bike  2021-07-18 20:21:15
# 4      3550C64E6994B8BC  classic_bike  2021-07-08 18:19:07
# ...                 ...           ...                  ...
# 82544  908E437B7FAF3594  classic_bike  2021-07-23 15:49:32
# 82545  A7B392863F10E25F  classic_bike  2021-07-22 18:24:51
# 82546  DBF9FEE943C6FA3E  classic_bike  2021-07-23 22:40:11
# 82547  B3C1437E53E71A8F  classic_bike  2021-07-28 23:10:20
# 82548  16DF52E670465D19  classic_bike  2021-07-05 16:28:48
#
#              end timestamp          start station name start station ID  \
# 0      2021-07-31 14:47:00     Bergen Ave & Stegman St            JC108
# 1      2021-07-17 19:20:07     Bergen Ave & Stegman St            JC108
# ...

# %%
renamed_df["rideable type"].value_counts()
# Out:
# classic_bike              80315
# docked_bike                1683
# motivate_dockless_bike        1
# Name: rideable type, dtype: int64

# %%
renamed_df.drop(renamed_df.index[renamed_df['rideable type'] == 'motivate_dockless_bike'], inplace = True)

# %%
renamed_df.count()
# Out:
# rideID                81998
# rideable type         81998
# start timestamp       81998
# end timestamp         81998
# start station name    81998
# start station ID      81998
# end station name      81998
# end station ID        81998
# start latitude        81998
# start longitude       81998
# end latitude          81998
# end longitude         81998
#  member/casual        81998
# start date            81998
# start time            81998
# end date              81998
# end time              81998
# dtype: int64

# %%
renamed_df["rideable type"].value_counts()
# Out:
# classic_bike    80315
# docked_bike      1683
# Name: rideable type, dtype: int64

# %%
# Change name of value "docked_bike" in "rideable type" column
renamed_df["rideable type"] = renamed_df["rideable type"].replace(["docked_bike"],["docked bike"])
renamed_df["rideable type"] = renamed_df["rideable type"].replace(["classic_bike"],["classic bike"])
renamed_df
# Out:
#                  rideID rideable type      start timestamp  \
# 0      2F01C15ECE379AE7  classic bike  2021-07-31 13:53:26
# 1      CF7E2039ACB179C2  classic bike  2021-07-17 19:06:01
# 2      9375052379DE50FC  classic bike  2021-07-08 19:54:34
# 3      EF77D67D538E108E  classic bike  2021-07-18 20:21:15
# 4      3550C64E6994B8BC  classic bike  2021-07-08 18:19:07
# ...                 ...           ...                  ...
# 82544  908E437B7FAF3594  classic bike  2021-07-23 15:49:32
# 82545  A7B392863F10E25F  classic bike  2021-07-22 18:24:51
# 82546  DBF9FEE943C6FA3E  classic bike  2021-07-23 22:40:11
# 82547  B3C1437E53E71A8F  classic bike  2021-07-28 23:10:20
# 82548  16DF52E670465D19  classic bike  2021-07-05 16:28:48
#
#              end timestamp          start station name start station ID  \
# 0      2021-07-31 14:47:00     Bergen Ave & Stegman St            JC108
# 1      2021-07-17 19:20:07     Bergen Ave & Stegman St            JC108
# ...

# %%
# Export final wildfires_data file as a CSV
renamed_df.to_csv("Resources/citibike-data-202107.csv", index=False, header=True)
