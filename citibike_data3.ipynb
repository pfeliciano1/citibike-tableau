# %%
# Dependencies
import pandas as pd

# %%
# Name of the CSV file
file = 'Resources/JC-202103-citibike-tripdata.csv'

# %%
# Taking the file and converting into dataframe
df = pd.read_csv(file, encoding="ISO-8859-1")
df
# Out:
#                 ride_id rideable_type           started_at  \
# 0      ABBBB4D89C620898   docked_bike  2021-03-03 10:32:07
# 1      987BC8C414C77F3E   docked_bike  2021-03-14 00:21:37
# 2      342C5C515F0F8BCB   docked_bike  2021-03-21 14:39:46
# 3      AB28945141163E31   docked_bike  2021-03-14 00:27:21
# 4      4F5758803BC3DE72   docked_bike  2021-03-12 20:45:29
# ...                 ...           ...                  ...
# 17118  6749C4D091AAA8CA   docked_bike  2021-03-29 19:30:20
# 17119  3DBAB9D9FA2758A3   docked_bike  2021-03-12 18:49:06
# 17120  E0183D5DD0C62E12   docked_bike  2021-03-28 12:29:15
# 17121  D39E4D9D8F735AB8   docked_bike  2021-03-23 13:03:35
# 17122  87D47774A82633A6   docked_bike  2021-03-24 10:12:54
#
#                   ended_at start_station_name start_station_id  \
# 0      2021-03-03 10:32:40     Jackson Square            JC063
# 1      2021-03-14 00:22:59     Jackson Square            JC063
# 2      2021-03-21 15:33:10     Jackson Square            JC063
# 3      2021-03-14 00:31:07     Jackson Square            JC063
# 4      2021-03-13 08:58:59     Jackson Square            JC063
# ...                    ...                ...              ...
# 17118  2021-03-29 19:38:10         Harborside            JC104
# 17119  2021-03-12 18:54:35         Harborside            JC104
# 17120  2021-03-28 12:34:40         Harborside            JC104
# 17121  2021-03-23 13:10:25         Harborside            JC104
# 17122  2021-03-24 10:21:17         Harborside            JC104
#
#       end_station_name end_station_id  start_lat  start_lng    end_lat  \
# 0       Jackson Square          JC063  40.711130 -74.078900  40.711130
# 1       Jackson Square          JC063  40.711130 -74.078900  40.711130
# 2            Warren St          JC006  40.711130 -74.078900  40.721124
# 3       Jackson Square          JC063  40.711130 -74.078900  40.711130
# 4       Jackson Square          JC063  40.711130 -74.078900  40.711130
# ...                ...            ...        ...        ...        ...
# 17118     Morris Canal          JC072  40.719251 -74.034234  40.712419
# 17119     Morris Canal          JC072  40.719251 -74.034234  40.712419
# 17120       Newark Ave          JC032  40.719251 -74.034234  40.721525
# 17121       Newark Ave          JC032  40.719251 -74.034234  40.721525
# 17122       Newark Ave          JC032  40.719251 -74.034234  40.721525
#
#          end_lng member_casual
# 0     -74.078900        member
# 1     -74.078900        casual
# 2     -74.038051        casual
# 3     -74.078900        casual
# 4     -74.078900        member
# ...          ...           ...
# 17118 -74.038526        member
# 17119 -74.038526        member
# 17120 -74.046305        member
# 17121 -74.046305        member
# 17122 -74.046305        member
#
# [17123 rows x 13 columns]

# %%
df.dtypes
# Out:
# ride_id                object
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# start_station_id       object
# end_station_name       object
# end_station_id         object
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# dtype: object

# %%
# Identify incomplete rows
df.count()
# Out:
# ride_id               17123
# rideable_type         17123
# started_at            17123
# ended_at              17123
# start_station_name    17123
# start_station_id      17123
# end_station_name      17046
# end_station_id        17046
# start_lat             17123
# start_lng             17123
# end_lat               17046
# end_lng               17046
# member_casual         17123
# dtype: int64

# %%
# Drop all rows with missing information
clean_df = df.dropna(how='any')
clean_df
# Out:
#                 ride_id rideable_type           started_at  \
# 0      ABBBB4D89C620898   docked_bike  2021-03-03 10:32:07
# 1      987BC8C414C77F3E   docked_bike  2021-03-14 00:21:37
# 2      342C5C515F0F8BCB   docked_bike  2021-03-21 14:39:46
# 3      AB28945141163E31   docked_bike  2021-03-14 00:27:21
# 4      4F5758803BC3DE72   docked_bike  2021-03-12 20:45:29
# ...                 ...           ...                  ...
# 17118  6749C4D091AAA8CA   docked_bike  2021-03-29 19:30:20
# 17119  3DBAB9D9FA2758A3   docked_bike  2021-03-12 18:49:06
# 17120  E0183D5DD0C62E12   docked_bike  2021-03-28 12:29:15
# 17121  D39E4D9D8F735AB8   docked_bike  2021-03-23 13:03:35
# 17122  87D47774A82633A6   docked_bike  2021-03-24 10:12:54
#
#                   ended_at start_station_name start_station_id  \
# 0      2021-03-03 10:32:40     Jackson Square            JC063
# 1      2021-03-14 00:22:59     Jackson Square            JC063
# 2      2021-03-21 15:33:10     Jackson Square            JC063
# 3      2021-03-14 00:31:07     Jackson Square            JC063
# 4      2021-03-13 08:58:59     Jackson Square            JC063
# ...                    ...                ...              ...
# 17118  2021-03-29 19:38:10         Harborside            JC104
# 17119  2021-03-12 18:54:35         Harborside            JC104
# 17120  2021-03-28 12:34:40         Harborside            JC104
# 17121  2021-03-23 13:10:25         Harborside            JC104
# 17122  2021-03-24 10:21:17         Harborside            JC104
#
#       end_station_name end_station_id  start_lat  start_lng    end_lat  \
# 0       Jackson Square          JC063  40.711130 -74.078900  40.711130
# 1       Jackson Square          JC063  40.711130 -74.078900  40.711130
# 2            Warren St          JC006  40.711130 -74.078900  40.721124
# 3       Jackson Square          JC063  40.711130 -74.078900  40.711130
# 4       Jackson Square          JC063  40.711130 -74.078900  40.711130
# ...                ...            ...        ...        ...        ...
# 17118     Morris Canal          JC072  40.719251 -74.034234  40.712419
# 17119     Morris Canal          JC072  40.719251 -74.034234  40.712419
# 17120       Newark Ave          JC032  40.719251 -74.034234  40.721525
# 17121       Newark Ave          JC032  40.719251 -74.034234  40.721525
# 17122       Newark Ave          JC032  40.719251 -74.034234  40.721525
#
#          end_lng member_casual
# 0     -74.078900        member
# 1     -74.078900        casual
# 2     -74.038051        casual
# 3     -74.078900        casual
# 4     -74.078900        member
# ...          ...           ...
# 17118 -74.038526        member
# 17119 -74.038526        member
# 17120 -74.046305        member
# 17121 -74.046305        member
# 17122 -74.046305        member
#
# [17046 rows x 13 columns]

# %%
# Identify incomplete rows
clean_df.count()
# Out:
# ride_id               17046
# rideable_type         17046
# started_at            17046
# ended_at              17046
# start_station_name    17046
# start_station_id      17046
# end_station_name      17046
# end_station_id        17046
# start_lat             17046
# start_lng             17046
# end_lat               17046
# end_lng               17046
# member_casual         17046
# dtype: int64

# %%
clean_df['start date'] = pd.to_datetime(clean_df['started_at']).dt.date
clean_df['start time'] = pd.to_datetime(clean_df['started_at']).dt.time
clean_df['end date'] = pd.to_datetime(clean_df['ended_at']).dt.date
clean_df['end time'] = pd.to_datetime(clean_df['ended_at']).dt.time
clean_df
# Out:
# /Users/paulfeliciano/opt/anaconda3/envs/PythonAdvanced/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/paulfeliciano/opt/anaconda3/envs/PythonAdvanced/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/paulfeliciano/opt/anaconda3/envs/PythonAdvanced/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/paulfeliciano/opt/anaconda3/envs/PythonAdvanced/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#                 ride_id rideable_type           started_at  \
# 0      ABBBB4D89C620898   docked_bike  2021-03-03 10:32:07
# 1      987BC8C414C77F3E   docked_bike  2021-03-14 00:21:37
# 2      342C5C515F0F8BCB   docked_bike  2021-03-21 14:39:46
# 3      AB28945141163E31   docked_bike  2021-03-14 00:27:21
# 4      4F5758803BC3DE72   docked_bike  2021-03-12 20:45:29
# ...                 ...           ...                  ...
# 17118  6749C4D091AAA8CA   docked_bike  2021-03-29 19:30:20
# 17119  3DBAB9D9FA2758A3   docked_bike  2021-03-12 18:49:06
# 17120  E0183D5DD0C62E12   docked_bike  2021-03-28 12:29:15
# 17121  D39E4D9D8F735AB8   docked_bike  2021-03-23 13:03:35
# 17122  87D47774A82633A6   docked_bike  2021-03-24 10:12:54
#
#                   ended_at start_station_name start_station_id  \
# 0      2021-03-03 10:32:40     Jackson Square            JC063
# 1      2021-03-14 00:22:59     Jackson Square            JC063
# 2      2021-03-21 15:33:10     Jackson Square            JC063
# 3      2021-03-14 00:31:07     Jackson Square            JC063
# 4      2021-03-13 08:58:59     Jackson Square            JC063
# ...                    ...                ...              ...
# 17118  2021-03-29 19:38:10         Harborside            JC104
# 17119  2021-03-12 18:54:35         Harborside            JC104
# 17120  2021-03-28 12:34:40         Harborside            JC104
# 17121  2021-03-23 13:10:25         Harborside            JC104
# 17122  2021-03-24 10:21:17         Harborside            JC104
#
#       end_station_name end_station_id  start_lat  start_lng    end_lat  \
# 0       Jackson Square          JC063  40.711130 -74.078900  40.711130
# 1       Jackson Square          JC063  40.711130 -74.078900  40.711130
# 2            Warren St          JC006  40.711130 -74.078900  40.721124
# 3       Jackson Square          JC063  40.711130 -74.078900  40.711130
# 4       Jackson Square          JC063  40.711130 -74.078900  40.711130
# ...                ...            ...        ...        ...        ...
# 17118     Morris Canal          JC072  40.719251 -74.034234  40.712419
# 17119     Morris Canal          JC072  40.719251 -74.034234  40.712419
# 17120       Newark Ave          JC032  40.719251 -74.034234  40.721525
# 17121       Newark Ave          JC032  40.719251 -74.034234  40.721525
# 17122       Newark Ave          JC032  40.719251 -74.034234  40.721525
#
#          end_lng member_casual  start date start time    end date  end time
# 0     -74.078900        member  2021-03-03   10:32:07  2021-03-03  10:32:40
# 1     -74.078900        casual  2021-03-14   00:21:37  2021-03-14  00:22:59
# 2     -74.038051        casual  2021-03-21   14:39:46  2021-03-21  15:33:10
# 3     -74.078900        casual  2021-03-14   00:27:21  2021-03-14  00:31:07
# 4     -74.078900        member  2021-03-12   20:45:29  2021-03-13  08:58:59
# ...          ...           ...         ...        ...         ...       ...
# 17118 -74.038526        member  2021-03-29   19:30:20  2021-03-29  19:38:10
# 17119 -74.038526        member  2021-03-12   18:49:06  2021-03-12  18:54:35
# 17120 -74.046305        member  2021-03-28   12:29:15  2021-03-28  12:34:40
# 17121 -74.046305        member  2021-03-23   13:03:35  2021-03-23  13:10:25
# 17122 -74.046305        member  2021-03-24   10:12:54  2021-03-24  10:21:17
#
# [17046 rows x 17 columns]

# %%
renamed_df = clean_df.rename(columns={"ride_id": "rideID", "rideable_type": "rideable type", 
                                      "started_at": "start timestamp", "ended_at": "end timestamp",
                                      "start_station_name": "start station name", 
                                      "start_station_id": "start station ID", "end_station_name": "end station name", 
                                      "end_station_id": "end station ID", "start_lat": "start latitude",
                                      "start_lng": "start longitude", "end_lat": "end latitude", 
                                      "end_lng": "end longitude", "member_casual": " member/casual"})
renamed_df
# Out:
#                  rideID rideable type      start timestamp  \
# 0      ABBBB4D89C620898   docked_bike  2021-03-03 10:32:07
# 1      987BC8C414C77F3E   docked_bike  2021-03-14 00:21:37
# 2      342C5C515F0F8BCB   docked_bike  2021-03-21 14:39:46
# 3      AB28945141163E31   docked_bike  2021-03-14 00:27:21
# 4      4F5758803BC3DE72   docked_bike  2021-03-12 20:45:29
# ...                 ...           ...                  ...
# 17118  6749C4D091AAA8CA   docked_bike  2021-03-29 19:30:20
# 17119  3DBAB9D9FA2758A3   docked_bike  2021-03-12 18:49:06
# 17120  E0183D5DD0C62E12   docked_bike  2021-03-28 12:29:15
# 17121  D39E4D9D8F735AB8   docked_bike  2021-03-23 13:03:35
# 17122  87D47774A82633A6   docked_bike  2021-03-24 10:12:54
#
#              end timestamp start station name start station ID  \
# 0      2021-03-03 10:32:40     Jackson Square            JC063
# 1      2021-03-14 00:22:59     Jackson Square            JC063
# 2      2021-03-21 15:33:10     Jackson Square            JC063
# 3      2021-03-14 00:31:07     Jackson Square            JC063
# 4      2021-03-13 08:58:59     Jackson Square            JC063
# ...                    ...                ...              ...
# 17118  2021-03-29 19:38:10         Harborside            JC104
# 17119  2021-03-12 18:54:35         Harborside            JC104
# 17120  2021-03-28 12:34:40         Harborside            JC104
# 17121  2021-03-23 13:10:25         Harborside            JC104
# 17122  2021-03-24 10:21:17         Harborside            JC104
#
#       end station name end station ID  start latitude  start longitude  \
# 0       Jackson Square          JC063       40.711130       -74.078900
# 1       Jackson Square          JC063       40.711130       -74.078900
# 2            Warren St          JC006       40.711130       -74.078900
# 3       Jackson Square          JC063       40.711130       -74.078900
# 4       Jackson Square          JC063       40.711130       -74.078900
# ...                ...            ...             ...              ...
# 17118     Morris Canal          JC072       40.719251       -74.034234
# 17119     Morris Canal          JC072       40.719251       -74.034234
# 17120       Newark Ave          JC032       40.719251       -74.034234
# 17121       Newark Ave          JC032       40.719251       -74.034234
# 17122       Newark Ave          JC032       40.719251       -74.034234
#
#        end latitude  end longitude  member/casual  start date start time  \
# 0         40.711130     -74.078900         member  2021-03-03   10:32:07
# 1         40.711130     -74.078900         casual  2021-03-14   00:21:37
# 2         40.721124     -74.038051         casual  2021-03-21   14:39:46
# 3         40.711130     -74.078900         casual  2021-03-14   00:27:21
# 4         40.711130     -74.078900         member  2021-03-12   20:45:29
# ...             ...            ...            ...         ...        ...
# 17118     40.712419     -74.038526         member  2021-03-29   19:30:20
# 17119     40.712419     -74.038526         member  2021-03-12   18:49:06
# 17120     40.721525     -74.046305         member  2021-03-28   12:29:15
# 17121     40.721525     -74.046305         member  2021-03-23   13:03:35
# 17122     40.721525     -74.046305         member  2021-03-24   10:12:54
#
#          end date  end time
# 0      2021-03-03  10:32:40
# 1      2021-03-14  00:22:59
# 2      2021-03-21  15:33:10
# 3      2021-03-14  00:31:07
# 4      2021-03-13  08:58:59
# ...           ...       ...
# 17118  2021-03-29  19:38:10
# 17119  2021-03-12  18:54:35
# 17120  2021-03-28  12:34:40
# 17121  2021-03-23  13:10:25
# 17122  2021-03-24  10:21:17
#
# [17046 rows x 17 columns]

# %%
renamed_df["rideable type"].value_counts()
# Out:
# docked_bike    17046
# Name: rideable type, dtype: int64

# %%
# Change name of value "docked_bike" in "rideable type" column
renamed_df["rideable type"] = renamed_df["rideable type"].replace(["docked_bike"],["docked bike"])
renamed_df
# Out:
#                  rideID rideable type      start timestamp  \
# 0      ABBBB4D89C620898   docked bike  2021-03-03 10:32:07
# 1      987BC8C414C77F3E   docked bike  2021-03-14 00:21:37
# 2      342C5C515F0F8BCB   docked bike  2021-03-21 14:39:46
# 3      AB28945141163E31   docked bike  2021-03-14 00:27:21
# 4      4F5758803BC3DE72   docked bike  2021-03-12 20:45:29
# ...                 ...           ...                  ...
# 17118  6749C4D091AAA8CA   docked bike  2021-03-29 19:30:20
# 17119  3DBAB9D9FA2758A3   docked bike  2021-03-12 18:49:06
# 17120  E0183D5DD0C62E12   docked bike  2021-03-28 12:29:15
# 17121  D39E4D9D8F735AB8   docked bike  2021-03-23 13:03:35
# 17122  87D47774A82633A6   docked bike  2021-03-24 10:12:54
#
#              end timestamp start station name start station ID  \
# 0      2021-03-03 10:32:40     Jackson Square            JC063
# 1      2021-03-14 00:22:59     Jackson Square            JC063
# 2      2021-03-21 15:33:10     Jackson Square            JC063
# 3      2021-03-14 00:31:07     Jackson Square            JC063
# 4      2021-03-13 08:58:59     Jackson Square            JC063
# ...                    ...                ...              ...
# 17118  2021-03-29 19:38:10         Harborside            JC104
# 17119  2021-03-12 18:54:35         Harborside            JC104
# 17120  2021-03-28 12:34:40         Harborside            JC104
# 17121  2021-03-23 13:10:25         Harborside            JC104
# 17122  2021-03-24 10:21:17         Harborside            JC104
#
#       end station name end station ID  start latitude  start longitude  \
# 0       Jackson Square          JC063       40.711130       -74.078900
# 1       Jackson Square          JC063       40.711130       -74.078900
# 2            Warren St          JC006       40.711130       -74.078900
# 3       Jackson Square          JC063       40.711130       -74.078900
# 4       Jackson Square          JC063       40.711130       -74.078900
# ...                ...            ...             ...              ...
# 17118     Morris Canal          JC072       40.719251       -74.034234
# 17119     Morris Canal          JC072       40.719251       -74.034234
# 17120       Newark Ave          JC032       40.719251       -74.034234
# 17121       Newark Ave          JC032       40.719251       -74.034234
# 17122       Newark Ave          JC032       40.719251       -74.034234
#
#        end latitude  end longitude  member/casual  start date start time  \
# 0         40.711130     -74.078900         member  2021-03-03   10:32:07
# 1         40.711130     -74.078900         casual  2021-03-14   00:21:37
# 2         40.721124     -74.038051         casual  2021-03-21   14:39:46
# 3         40.711130     -74.078900         casual  2021-03-14   00:27:21
# 4         40.711130     -74.078900         member  2021-03-12   20:45:29
# ...             ...            ...            ...         ...        ...
# 17118     40.712419     -74.038526         member  2021-03-29   19:30:20
# 17119     40.712419     -74.038526         member  2021-03-12   18:49:06
# 17120     40.721525     -74.046305         member  2021-03-28   12:29:15
# 17121     40.721525     -74.046305         member  2021-03-23   13:03:35
# 17122     40.721525     -74.046305         member  2021-03-24   10:12:54
#
#          end date  end time
# 0      2021-03-03  10:32:40
# 1      2021-03-14  00:22:59
# 2      2021-03-21  15:33:10
# 3      2021-03-14  00:31:07
# 4      2021-03-13  08:58:59
# ...           ...       ...
# 17118  2021-03-29  19:38:10
# 17119  2021-03-12  18:54:35
# 17120  2021-03-28  12:34:40
# 17121  2021-03-23  13:10:25
# 17122  2021-03-24  10:21:17
#
# [17046 rows x 17 columns]

# %%
# Export final wildfires_data file as a CSV
renamed_df.to_csv("Resources/citibike-data-202103.csv", index=False, header=True)
