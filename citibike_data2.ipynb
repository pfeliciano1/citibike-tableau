# %%
# Dependencies
import pandas as pd

# %%
# Name of the CSV file
file = 'Resources/JC-202102-citibike-tripdata.csv'

# %%
# Taking the file and converting into dataframe
df = pd.read_csv(file, encoding="ISO-8859-1")
df
# Out:
#                ride_id rideable_type           started_at  \
# 0     121DD7DD23CB1335   docked_bike  2021-02-03 23:11:28
# 1     FD73FB85F008349D   docked_bike  2021-02-27 16:34:05
# 2     39F9E6663CB5FDF6   docked_bike  2021-02-26 23:16:04
# 3     A64745CB0792EC6F   docked_bike  2021-02-24 16:51:50
# 4     75CC76EB9543764A   docked_bike  2021-02-24 20:44:16
# ...                ...           ...                  ...
# 4876  3F8FD9A051C0E3DA   docked_bike  2021-02-24 18:05:45
# 4877  B91F3593C0C06D04   docked_bike  2021-02-22 18:22:04
# 4878  A790954A017D07CB   docked_bike  2021-02-13 12:21:49
# 4879  42B1932D06CEE034   docked_bike  2021-02-25 11:20:29
# 4880  F71732ECE7CD02CF   docked_bike  2021-02-19 13:59:22
#
#                  ended_at          start_station_name start_station_id  \
# 0     2021-02-03 23:18:28  Hoboken Ave at Monmouth St            JC105
# 1     2021-02-27 16:56:40                Newport Pkwy            JC008
# ...

# %%
df.dtypes
# Out:
# ride_id                object
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# start_station_id       object
# end_station_name       object
# end_station_id         object
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# dtype: object

# %%
# Identify incomplete rows
df.count()
# Out:
# ride_id               4881
# rideable_type         4881
# started_at            4881
# ended_at              4881
# start_station_name    4881
# start_station_id      4881
# end_station_name      4813
# end_station_id        4813
# start_lat             4881
# start_lng             4881
# end_lat               4813
# end_lng               4813
# member_casual         4881
# dtype: int64

# %%
# Drop all rows with missing information
clean_df = df.dropna(how='any')
clean_df
# Out:
#                ride_id rideable_type           started_at  \
# 0     121DD7DD23CB1335   docked_bike  2021-02-03 23:11:28
# 1     FD73FB85F008349D   docked_bike  2021-02-27 16:34:05
# 2     39F9E6663CB5FDF6   docked_bike  2021-02-26 23:16:04
# 3     A64745CB0792EC6F   docked_bike  2021-02-24 16:51:50
# 4     75CC76EB9543764A   docked_bike  2021-02-24 20:44:16
# ...                ...           ...                  ...
# 4876  3F8FD9A051C0E3DA   docked_bike  2021-02-24 18:05:45
# 4877  B91F3593C0C06D04   docked_bike  2021-02-22 18:22:04
# 4878  A790954A017D07CB   docked_bike  2021-02-13 12:21:49
# 4879  42B1932D06CEE034   docked_bike  2021-02-25 11:20:29
# 4880  F71732ECE7CD02CF   docked_bike  2021-02-19 13:59:22
#
#                  ended_at          start_station_name start_station_id  \
# 0     2021-02-03 23:18:28  Hoboken Ave at Monmouth St            JC105
# 1     2021-02-27 16:56:40                Newport Pkwy            JC008
# ...

# %%
# Identify incomplete rows
clean_df.count()
# Out:
# ride_id               4813
# rideable_type         4813
# started_at            4813
# ended_at              4813
# start_station_name    4813
# start_station_id      4813
# end_station_name      4813
# end_station_id        4813
# start_lat             4813
# start_lng             4813
# end_lat               4813
# end_lng               4813
# member_casual         4813
# dtype: int64

# %%
clean_df['start date'] = pd.to_datetime(clean_df['started_at']).dt.date
clean_df['start time'] = pd.to_datetime(clean_df['started_at']).dt.time
clean_df['end date'] = pd.to_datetime(clean_df['ended_at']).dt.date
clean_df['end time'] = pd.to_datetime(clean_df['ended_at']).dt.time
clean_df
# Out:
# /Users/paulfeliciano/opt/anaconda3/envs/PythonAdvanced/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/paulfeliciano/opt/anaconda3/envs/PythonAdvanced/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/paulfeliciano/opt/anaconda3/envs/PythonAdvanced/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# ...

# %%
renamed_df = clean_df.rename(columns={"ride_id": "rideID", "rideable_type": "rideable type", 
                                      "started_at": "start timestamp", "ended_at": "end timestamp",
                                      "start_station_name": "start station name", 
                                      "start_station_id": "start station ID", "end_station_name": "end station name", 
                                      "end_station_id": "end station ID", "start_lat": "start latitude",
                                      "start_lng": "start longitude", "end_lat": "end latitude", 
                                      "end_lng": "end longitude", "member_casual": " member/casual"})
renamed_df
# Out:
#                 rideID rideable type      start timestamp  \
# 0     121DD7DD23CB1335   docked_bike  2021-02-03 23:11:28
# 1     FD73FB85F008349D   docked_bike  2021-02-27 16:34:05
# 2     39F9E6663CB5FDF6   docked_bike  2021-02-26 23:16:04
# 3     A64745CB0792EC6F   docked_bike  2021-02-24 16:51:50
# 4     75CC76EB9543764A   docked_bike  2021-02-24 20:44:16
# ...                ...           ...                  ...
# 4876  3F8FD9A051C0E3DA   docked_bike  2021-02-24 18:05:45
# 4877  B91F3593C0C06D04   docked_bike  2021-02-22 18:22:04
# 4878  A790954A017D07CB   docked_bike  2021-02-13 12:21:49
# 4879  42B1932D06CEE034   docked_bike  2021-02-25 11:20:29
# 4880  F71732ECE7CD02CF   docked_bike  2021-02-19 13:59:22
#
#             end timestamp          start station name start station ID  \
# 0     2021-02-03 23:18:28  Hoboken Ave at Monmouth St            JC105
# 1     2021-02-27 16:56:40                Newport Pkwy            JC008
# ...

# %%
renamed_df["rideable type"].value_counts()
# Out:
# docked_bike    4813
# Name: rideable type, dtype: int64

# %%
# Change name of value "docked_bike" in "rideable type" column
renamed_df["rideable type"] = renamed_df["rideable type"].replace(["docked_bike"],["docked bike"])
renamed_df
# Out:
#                 rideID rideable type      start timestamp  \
# 0     121DD7DD23CB1335   docked bike  2021-02-03 23:11:28
# 1     FD73FB85F008349D   docked bike  2021-02-27 16:34:05
# 2     39F9E6663CB5FDF6   docked bike  2021-02-26 23:16:04
# 3     A64745CB0792EC6F   docked bike  2021-02-24 16:51:50
# 4     75CC76EB9543764A   docked bike  2021-02-24 20:44:16
# ...                ...           ...                  ...
# 4876  3F8FD9A051C0E3DA   docked bike  2021-02-24 18:05:45
# 4877  B91F3593C0C06D04   docked bike  2021-02-22 18:22:04
# 4878  A790954A017D07CB   docked bike  2021-02-13 12:21:49
# 4879  42B1932D06CEE034   docked bike  2021-02-25 11:20:29
# 4880  F71732ECE7CD02CF   docked bike  2021-02-19 13:59:22
#
#             end timestamp          start station name start station ID  \
# 0     2021-02-03 23:18:28  Hoboken Ave at Monmouth St            JC105
# 1     2021-02-27 16:56:40                Newport Pkwy            JC008
# ...

# %%
# Export final wildfires_data file as a CSV
renamed_df.to_csv("Resources/citibike-data-202102.csv", index=False, header=True)
