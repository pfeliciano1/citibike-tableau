# %%
# Dependencies
import pandas as pd

# %%
# Name of the CSV file
file = 'Resources/JC-202101-citibike-tripdata.csv'

# %%
# Taking the file and converting into dataframe
df = pd.read_csv(file, encoding="ISO-8859-1")
df
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               266  2021-01-01 00:03:35.5100  2021-01-01 00:08:01.7770
# 1              1543  2021-01-01 00:23:32.9250  2021-01-01 00:49:16.0830
# 2              1461  2021-01-01 00:23:50.7940  2021-01-01 00:48:12.5660
# 3               793  2021-01-01 00:31:09.0770  2021-01-01 00:44:22.9430
# 4               596  2021-01-01 00:35:52.1900  2021-01-01 00:45:48.7740
# ...             ...                       ...                       ...
# 11619          2476  2021-01-31 20:16:05.4700  2021-01-31 20:57:22.0110
# 11620           147  2021-01-31 21:05:05.2090  2021-01-31 21:07:32.8660
# 11621           660  2021-01-31 21:06:23.5880  2021-01-31 21:17:23.8420
# 11622           384  2021-01-31 21:16:37.8220  2021-01-31 21:23:02.1240
# 11623           356  2021-01-31 23:24:50.8810  2021-01-31 23:30:47.3030
#
#        start station id start station name  start station latitude  \
# ...

# %%
# Convert tripduration column from seconds to minutes
# df["tripduration"] = (df["tripduration"])/60
df['tripduration'] = pd.to_datetime(df["tripduration"], unit='s').dt.strftime("%H:%M:%S")
df
# Out:
#       tripduration                 starttime                  stoptime  \
# 0         00:04:26  2021-01-01 00:03:35.5100  2021-01-01 00:08:01.7770
# 1         00:25:43  2021-01-01 00:23:32.9250  2021-01-01 00:49:16.0830
# 2         00:24:21  2021-01-01 00:23:50.7940  2021-01-01 00:48:12.5660
# 3         00:13:13  2021-01-01 00:31:09.0770  2021-01-01 00:44:22.9430
# 4         00:09:56  2021-01-01 00:35:52.1900  2021-01-01 00:45:48.7740
# ...            ...                       ...                       ...
# 11619     00:41:16  2021-01-31 20:16:05.4700  2021-01-31 20:57:22.0110
# 11620     00:02:27  2021-01-31 21:05:05.2090  2021-01-31 21:07:32.8660
# 11621     00:11:00  2021-01-31 21:06:23.5880  2021-01-31 21:17:23.8420
# 11622     00:06:24  2021-01-31 21:16:37.8220  2021-01-31 21:23:02.1240
# 11623     00:05:56  2021-01-31 23:24:50.8810  2021-01-31 23:30:47.3030
#
#        start station id start station name  start station latitude  \
# ...

# %%
# Replace gender values: 0 = unknown, 1 = male, 2 = female
df['gender'] = df['gender'].map({0:'unknown', 1:'male', 2:'female'})
df
# Out:
#       tripduration                 starttime                  stoptime  \
# 0         00:04:26  2021-01-01 00:03:35.5100  2021-01-01 00:08:01.7770
# 1         00:25:43  2021-01-01 00:23:32.9250  2021-01-01 00:49:16.0830
# 2         00:24:21  2021-01-01 00:23:50.7940  2021-01-01 00:48:12.5660
# 3         00:13:13  2021-01-01 00:31:09.0770  2021-01-01 00:44:22.9430
# 4         00:09:56  2021-01-01 00:35:52.1900  2021-01-01 00:45:48.7740
# ...            ...                       ...                       ...
# 11619     00:41:16  2021-01-31 20:16:05.4700  2021-01-31 20:57:22.0110
# 11620     00:02:27  2021-01-31 21:05:05.2090  2021-01-31 21:07:32.8660
# 11621     00:11:00  2021-01-31 21:06:23.5880  2021-01-31 21:17:23.8420
# 11622     00:06:24  2021-01-31 21:16:37.8220  2021-01-31 21:23:02.1240
# 11623     00:05:56  2021-01-31 23:24:50.8810  2021-01-31 23:30:47.3030
#
#        start station id start station name  start station latitude  \
# ...

# %%
df.dtypes
# Out:
# tripduration                object
# starttime                   object
# stoptime                    object
# start station id             int64
# start station name          object
# start station latitude     float64
# start station longitude    float64
# end station id               int64
# end station name            object
# end station latitude       float64
# end station longitude      float64
# bikeid                       int64
# usertype                    object
# birth year                   int64
# gender                      object
# dtype: object

# %%
df['start date'] = pd.to_datetime(df['starttime']).dt.date
df['start time'] = pd.to_datetime(df['starttime']).dt.time
df['end date'] = pd.to_datetime(df['stoptime']).dt.date
df['end time'] = pd.to_datetime(df['stoptime']).dt.time
df
# Out:
#       tripduration                 starttime                  stoptime  \
# 0         00:04:26  2021-01-01 00:03:35.5100  2021-01-01 00:08:01.7770
# 1         00:25:43  2021-01-01 00:23:32.9250  2021-01-01 00:49:16.0830
# 2         00:24:21  2021-01-01 00:23:50.7940  2021-01-01 00:48:12.5660
# 3         00:13:13  2021-01-01 00:31:09.0770  2021-01-01 00:44:22.9430
# 4         00:09:56  2021-01-01 00:35:52.1900  2021-01-01 00:45:48.7740
# ...            ...                       ...                       ...
# 11619     00:41:16  2021-01-31 20:16:05.4700  2021-01-31 20:57:22.0110
# 11620     00:02:27  2021-01-31 21:05:05.2090  2021-01-31 21:07:32.8660
# 11621     00:11:00  2021-01-31 21:06:23.5880  2021-01-31 21:17:23.8420
# 11622     00:06:24  2021-01-31 21:16:37.8220  2021-01-31 21:23:02.1240
# 11623     00:05:56  2021-01-31 23:24:50.8810  2021-01-31 23:30:47.3030
#
#        start station id start station name  start station latitude  \
# ...

# %%
# Identify incomplete rows
df.count()
# Out:
# tripduration               11624
# starttime                  11624
# stoptime                   11624
# start station id           11624
# start station name         11624
# start station latitude     11624
# start station longitude    11624
# end station id             11624
# end station name           11624
# end station latitude       11624
# end station longitude      11624
# bikeid                     11624
# usertype                   11624
# birth year                 11624
# gender                     11624
# start date                 11624
# start time                 11624
# end date                   11624
# end time                   11624
# dtype: int64

# %%
df = df.rename(columns={"tripduration":"trip duration", "usertype": "user type",
                        "starttime":"start time", "stoptime": "stop time"})
df
# Out:
#       trip duration                start time                 stop time  \
# 0          00:04:26  2021-01-01 00:03:35.5100  2021-01-01 00:08:01.7770
# 1          00:25:43  2021-01-01 00:23:32.9250  2021-01-01 00:49:16.0830
# 2          00:24:21  2021-01-01 00:23:50.7940  2021-01-01 00:48:12.5660
# 3          00:13:13  2021-01-01 00:31:09.0770  2021-01-01 00:44:22.9430
# 4          00:09:56  2021-01-01 00:35:52.1900  2021-01-01 00:45:48.7740
# ...             ...                       ...                       ...
# 11619      00:41:16  2021-01-31 20:16:05.4700  2021-01-31 20:57:22.0110
# 11620      00:02:27  2021-01-31 21:05:05.2090  2021-01-31 21:07:32.8660
# 11621      00:11:00  2021-01-31 21:06:23.5880  2021-01-31 21:17:23.8420
# 11622      00:06:24  2021-01-31 21:16:37.8220  2021-01-31 21:23:02.1240
# 11623      00:05:56  2021-01-31 23:24:50.8810  2021-01-31 23:30:47.3030
#
#        start station id start station name  start station latitude  \
# ...

# %%
# Export final wildfires_data file as a CSV
df.to_csv("Resources/citibike-data-202101.csv", index=False, header=True)
