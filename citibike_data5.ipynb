# %%
# Dependencies
import pandas as pd

# %%
# Name of the CSV file
file = 'Resources/JC-202105-citibike-tripdata.csv'

# %%
# Taking the file and converting into dataframe
df = pd.read_csv(file, encoding="ISO-8859-1")
df
# Out:
#                 ride_id rideable_type           started_at  \
# 0      74A4206E7487CBC9   docked_bike  2021-05-23 16:51:00
# 1      58EEE2950FFE01CE   docked_bike  2021-05-31 16:54:47
# 2      1429D912C16EEE59   docked_bike  2021-05-25 16:19:34
# 3      FE9C5B74167CBCCD   docked_bike  2021-05-22 17:32:19
# 4      B88D37626F000BBA   docked_bike  2021-05-14 09:48:34
# ...                 ...           ...                  ...
# 45038  62FF3FEDAAD7FCB3   docked_bike  2021-05-31 12:46:22
# 45039  E742AEA7068E0E4A   docked_bike  2021-05-31 16:34:19
# 45040  E769F9EE96D6433A   docked_bike  2021-05-17 22:52:35
# 45041  EC973614DCA179A2   docked_bike  2021-05-31 20:48:58
# 45042  3571180FE5C52CB1   docked_bike  2021-05-23 14:28:43
#
#                   ended_at             start_station_name start_station_id  \
# 0      2021-05-23 18:38:21  9 St HBLR - Jackson St & 8 St            HB305
# 1      2021-05-31 16:55:28  9 St HBLR - Jackson St & 8 St            HB305
# ...

# %%
df.dtypes
# Out:
# ride_id                object
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# start_station_id       object
# end_station_name       object
# end_station_id         object
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# dtype: object

# %%
# Identify incomplete rows
df.count()
# Out:
# ride_id               45043
# rideable_type         45043
# started_at            45043
# ended_at              45043
# start_station_name    45043
# start_station_id      45043
# end_station_name      44954
# end_station_id        44954
# start_lat             45043
# start_lng             45043
# end_lat               44954
# end_lng               44954
# member_casual         45043
# dtype: int64

# %%
# Drop all rows with missing information
clean_df = df.dropna(how='any')
clean_df
# Out:
#                 ride_id rideable_type           started_at  \
# 0      74A4206E7487CBC9   docked_bike  2021-05-23 16:51:00
# 1      58EEE2950FFE01CE   docked_bike  2021-05-31 16:54:47
# 2      1429D912C16EEE59   docked_bike  2021-05-25 16:19:34
# 3      FE9C5B74167CBCCD   docked_bike  2021-05-22 17:32:19
# 4      B88D37626F000BBA   docked_bike  2021-05-14 09:48:34
# ...                 ...           ...                  ...
# 45038  62FF3FEDAAD7FCB3   docked_bike  2021-05-31 12:46:22
# 45039  E742AEA7068E0E4A   docked_bike  2021-05-31 16:34:19
# 45040  E769F9EE96D6433A   docked_bike  2021-05-17 22:52:35
# 45041  EC973614DCA179A2   docked_bike  2021-05-31 20:48:58
# 45042  3571180FE5C52CB1   docked_bike  2021-05-23 14:28:43
#
#                   ended_at             start_station_name start_station_id  \
# 0      2021-05-23 18:38:21  9 St HBLR - Jackson St & 8 St            HB305
# 1      2021-05-31 16:55:28  9 St HBLR - Jackson St & 8 St            HB305
# ...

# %%
# Identify incomplete rows
clean_df.count()
# Out:
# ride_id               44954
# rideable_type         44954
# started_at            44954
# ended_at              44954
# start_station_name    44954
# start_station_id      44954
# end_station_name      44954
# end_station_id        44954
# start_lat             44954
# start_lng             44954
# end_lat               44954
# end_lng               44954
# member_casual         44954
# dtype: int64

# %%
clean_df['start date'] = pd.to_datetime(clean_df['started_at']).dt.date
clean_df['start time'] = pd.to_datetime(clean_df['started_at']).dt.time
clean_df['end date'] = pd.to_datetime(clean_df['ended_at']).dt.date
clean_df['end time'] = pd.to_datetime(clean_df['ended_at']).dt.time
clean_df
# Out:
# /Users/paulfeliciano/opt/anaconda3/envs/PythonAdvanced/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/paulfeliciano/opt/anaconda3/envs/PythonAdvanced/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/paulfeliciano/opt/anaconda3/envs/PythonAdvanced/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# ...

# %%
renamed_df = clean_df.rename(columns={"ride_id": "rideID", "rideable_type": "rideable type", 
                                      "started_at": "start timestamp", "ended_at": "end timestamp",
                                      "start_station_name": "start station name", 
                                      "start_station_id": "start station ID", "end_station_name": "end station name", 
                                      "end_station_id": "end station ID", "start_lat": "start latitude",
                                      "start_lng": "start longitude", "end_lat": "end latitude", 
                                      "end_lng": "end longitude", "member_casual": " member/casual"})
renamed_df
# Out:
#                  rideID rideable type      start timestamp  \
# 0      74A4206E7487CBC9   docked_bike  2021-05-23 16:51:00
# 1      58EEE2950FFE01CE   docked_bike  2021-05-31 16:54:47
# 2      1429D912C16EEE59   docked_bike  2021-05-25 16:19:34
# 3      FE9C5B74167CBCCD   docked_bike  2021-05-22 17:32:19
# 4      B88D37626F000BBA   docked_bike  2021-05-14 09:48:34
# ...                 ...           ...                  ...
# 45038  62FF3FEDAAD7FCB3   docked_bike  2021-05-31 12:46:22
# 45039  E742AEA7068E0E4A   docked_bike  2021-05-31 16:34:19
# 45040  E769F9EE96D6433A   docked_bike  2021-05-17 22:52:35
# 45041  EC973614DCA179A2   docked_bike  2021-05-31 20:48:58
# 45042  3571180FE5C52CB1   docked_bike  2021-05-23 14:28:43
#
#              end timestamp             start station name start station ID  \
# 0      2021-05-23 18:38:21  9 St HBLR - Jackson St & 8 St            HB305
# 1      2021-05-31 16:55:28  9 St HBLR - Jackson St & 8 St            HB305
# ...

# %%
renamed_df["rideable type"].value_counts()
# Out:
# docked_bike    44954
# Name: rideable type, dtype: int64

# %%
# Change name of value "docked_bike" in "rideable type" column
renamed_df["rideable type"] = renamed_df["rideable type"].replace(["docked_bike"],["docked bike"])
renamed_df
# Out:
#                  rideID rideable type      start timestamp  \
# 0      74A4206E7487CBC9   docked bike  2021-05-23 16:51:00
# 1      58EEE2950FFE01CE   docked bike  2021-05-31 16:54:47
# 2      1429D912C16EEE59   docked bike  2021-05-25 16:19:34
# 3      FE9C5B74167CBCCD   docked bike  2021-05-22 17:32:19
# 4      B88D37626F000BBA   docked bike  2021-05-14 09:48:34
# ...                 ...           ...                  ...
# 45038  62FF3FEDAAD7FCB3   docked bike  2021-05-31 12:46:22
# 45039  E742AEA7068E0E4A   docked bike  2021-05-31 16:34:19
# 45040  E769F9EE96D6433A   docked bike  2021-05-17 22:52:35
# 45041  EC973614DCA179A2   docked bike  2021-05-31 20:48:58
# 45042  3571180FE5C52CB1   docked bike  2021-05-23 14:28:43
#
#              end timestamp             start station name start station ID  \
# 0      2021-05-23 18:38:21  9 St HBLR - Jackson St & 8 St            HB305
# 1      2021-05-31 16:55:28  9 St HBLR - Jackson St & 8 St            HB305
# ...

# %%
# Export final wildfires_data file as a CSV
renamed_df.to_csv("Resources/citibike-data-202105.csv", index=False, header=True)
